# %%
import cv2
import numpy as np

from matplotlib import pyplot as plt

# %%
image = cv2.imread('images/profile.jpg', 0)
image
# Out:
# array([[144, 145, 146, ..., 239, 240, 240],
#        [144, 145, 146, ..., 240, 240, 241],
#        [144, 145, 146, ..., 241, 242, 242],
#        ...,
#        [141, 140, 140, ..., 247, 247, 247],
#        [141, 140, 140, ..., 247, 247, 247],
#        [140, 140, 139, ..., 247, 247, 247]], dtype=uint8)

# %%
sobel_x = cv2.Sobel(image, -1, 1, 0, ksize=5)
plt.imshow(sobel_x, cmap='gray')
plt.show()

# %%
sobel_y = cv2.Sobel(image, -1, 0, 1, ksize=5)
plt.imshow(sobel_y, cmap='gray')
plt.show()
